# %%
# noteevents = pd.read_csv(r'/content/drive/MyDrive/AlgoIntern/Data/NOTEEVENTS.csv')

# %%
# noteevents.loc[noteevents.HADM_ID.isna()]

# %%
# #----------Different note categories of noteevents table -----------#
# note_categories = noteevents.CATEGORY.unique()

# %%
# note_categories

# %%
# #------------ISERROR column that has error--------#
# noteevents.loc[noteevents.ISERROR==1].count()

# %%
# #-----------Created csv files for each category-----------#
# path = '/content/drive/MyDrive/AlgoIntern/Data/Data1.0'
# for category in note_categories:
#   noteevents.loc[noteevents.CATEGORY==category].to_csv(
#       path+'/'+''.join(re.split('\s|/',category))+'.csv',
#       index=False)

# %%
# #----------working of the above join split command-----------#
# ''.join(re.split('\s|/','discharge/summary'))

# %%
# discharge_summary = pd.read_csv('/content/drive/MyDrive/AlgoIntern/Data/Data1.0/Dischargesummary.csv')

# %%
# #----------checking the if the discharge summary has ISERROR=1--------- (there is no error)
# discharge_summary.loc[discharge_summary.ISERROR==1]

# %%
# discharge_summary_trim = discharge_summary[['HADM_ID', 'CATEGORY', 'DESCRIPTION', 'TEXT']]

# %%
# # -------- saving the discharge summary with the required columns------#
# discharge_summary_trim.to_csv('/content/drive/MyDrive/AlgoIntern/Data/Data1.0/discharge_summary.csv',index=False)
